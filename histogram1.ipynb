# %% [markdown]
# <a href="https://colab.research.google.com/github/kajall120/Data_science_Lab_SE_64/blob/main/histogram1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define parameters
mean = 0
std_dev = 1
size = 50

# Generate normal distribution
data = np.random.normal(mean, std_dev, size)

# Print the generated data
print("data set values:",data)


# Plot histogram
plt.hist(data, bins=30, color='blue', edgecolor='black')

plt.title("Normal Distribution Histogram")
plt.xlabel("Values")
plt.ylabel("Frequency")

plt.show()
# Out:
# data set values: [-0.33375948  0.63797679 -0.23802725  0.13190692 -0.09387259 -0.72135512
#   1.41374541 -0.08421691 -0.882011   -0.28606585  0.49495236  1.2491934
#   0.21866754 -0.21421886  0.6018641  -0.84016207 -1.55371265  0.09127035
#   0.30029238 -0.26084945 -0.82896511  1.10434795  0.55862062  0.83331526
#   1.57059144  0.5755164   0.55867629  0.8287459  -0.56272704 -0.54412092
#  -0.0022804  -0.70669236 -0.03235448 -0.94103897  0.42301999 -0.67413411
#   0.05565329  0.64065687  0.42772363 -0.75830415  0.07033583  0.4471034
#   0.26736627 -0.33265748  0.52226142 -0.09246924  0.03283599 -0.5668168
#  -0.30869466  0.2549998 ]
