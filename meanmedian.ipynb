# %% [markdown]
# <a href="https://colab.research.google.com/github/kajall120/Data_science_Lab_SE_64/blob/main/meanmedian.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This program calculates the mean, median, variance, and standard deviation of a dataset provided by the user. It uses the `numpy` library for efficient numerical computations.

# %%
import numpy as np

def calculate_statistics():
    while True:
        user_input = input("Enter your dataset as a comma-separated list of numbers (e.g., 1,2,3,4,5): ")
        try:

            data = [float(x.strip()) for x in user_input.split(',')]
            if not data: # Check if the list is empty after conversion
                print("No valid numbers entered. Please try again.")
                continue
            break
        except ValueError:
            print("Invalid input. Please make sure all values are numbers and separated by commas.")


    data_array = np.array(data)


    mean_val = np.mean(data_array)
    median_val = np.median(data_array)
    variance_val = np.var(data_array)
    std_dev_val = np.std(data_array)


    print(f"\nDataset: {data}")
    print(f"Mean: {mean_val:.2f}")
    print(f"Median: {median_val:.2f}")
    print(f"Variance: {variance_val:.2f}")
    print(f"Standard Deviation: {std_dev_val:.2f}")


calculate_statistics()
# Out:
# Enter your dataset as a comma-separated list of numbers (e.g., 1,2,3,4,5): 10,20,30,40,50
#
# Dataset: [10.0, 20.0, 30.0, 40.0, 50.0]
# Mean: 30.00
# Median: 30.00
# Variance: 200.00
# Standard Deviation: 14.14
