# %% [markdown]
# <a href="https://colab.research.google.com/github/kajall120/Data_science_Lab_SE_64/blob/main/Even_odd.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def check_odd_even(number):
    """
    Checks if a given number is odd or even.

    Args:
        number (int): The number to check.

    Returns:
        str: 'Even' if the number is even, 'Odd' if the number is odd.
    """
    if number % 2 == 0:
        return "Even"
    else:
        return "Odd"

# Example usage:
num1 = 7
print(f"The number {num1} is {check_odd_even(num1)}.")

num2 = 10
print(f"The number {num2} is {check_odd_even(num2)}.")

num3 = 0
print(f"The number {num3} is {check_odd_even(num3)}.")
# Out:
# The number 7 is Odd.
# The number 10 is Even.
# The number 0 is Even.
