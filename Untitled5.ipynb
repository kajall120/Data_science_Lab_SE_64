# %% [markdown]
# <a href="https://colab.research.google.com/github/kajall120/Data_science_Lab_SE_64/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Define a 3x3 matrix
matrix = np.array([[1, 2, 3],
                   [4, 5, 6],
                   [4, 8, 9]])

print("The 3x3 matrix is:")
print(matrix)
# Out:
# The 3x3 matrix is:
# [[1 2 3]
#  [4 5 6]
#  [4 8 9]]

# %%
# Compute the determinant of the matrix
determinant = np.linalg.det(matrix)

print(f"\nThe determinant of the matrix is: {determinant}")
# Out:
# The determinant of the matrix is: 9.000000000000002
