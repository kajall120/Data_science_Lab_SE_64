# %% [markdown]
# <a href="https://colab.research.google.com/github/kajall120/Data_science_Lab_SE_64/blob/main/histrogram.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define parameters
mean = 0
std_dev = 1
size = 1000

# Generate normal distribution
data = np.random.normal(mean, std_dev, size)

# Plot histogram
plt.hist(data, bins=30, color='blue', edgecolor='black')

plt.title("Normal Distribution Histogram")
plt.xlabel("Values")
plt.ylabel("Frequency")

plt.show()
