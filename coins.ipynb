# %% [markdown]
# <a href="https://colab.research.google.com/github/kajall120/Data_science_Lab_SE_64/blob/main/coins.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

# take input from user
n = int(input("Enter number of coin tosses: "))

heads = 0
tails = 0

# simulate coin toss
for i in range(n):
    toss = random.choice(["H", "T"])

    if toss == "H":
        heads += 1
    else:
        tails += 1

# compute probabilities
p_heads = heads / n
p_tails = tails / n

print("Number of Heads:", heads)
print("Number of Tails:", tails)
print("Probability of Heads:", p_heads)
print("Probability of Tails:", p_tails)
# Out:
# Enter number of coin tosses: 2
# Number of Heads: 0
# Number of Tails: 2
# Probability of Heads: 0.0
# Probability of Tails: 1.0
