# %% [markdown]
# <a href="https://colab.research.google.com/github/kajall120/Data_science_Lab_SE_64/blob/main/factorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def factorial(n):
    if n < 0:
        return "Factorial is not defined for negative numbers."
    elif n == 0:
        return 1
    else:
        fact = 1
        for i in range(1, n + 1):
            fact *= i
        return fact


while True:
    try:
        num_str = input("Enter a non-negative integer to compute its factorial: ")
        num = int(num_str)
        if num >= 0:
            break
        else:
            print("Please enter a non-negative integer.")
    except ValueError:
        print("Invalid input. Please enter an integer.")


result = factorial(num)
print(f"The factorial of {num} is: {result}")
# Out:
# Enter a non-negative integer to compute its factorial: 7
# The factorial of 7 is: 5040
